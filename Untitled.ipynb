# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import sklearn

# %%
df1 = pd.read_csv('wustl-ehms-2020.csv')

# %%
df1.head()
# Out:
#      Dir        Flgs     SrcAddr     DstAddr  Sport  Dport  SrcBytes  \
# 0     ->   e          10.0.1.172  10.0.1.150  58059   1111     496.0
# 1     ->   e          10.0.1.172  10.0.1.150  58062   1111     496.0
# 2     ->   e          10.0.1.172  10.0.1.150  58065   1111     496.0
# 3     ->   e          10.0.1.172  10.0.1.150  58067   1111     496.0
# 4     ->   e          10.0.1.172  10.0.1.150  58069   1111     496.0
#
#    DstBytes   SrcLoad  DstLoad  ...  Packet_num  Temp  SpO2  Pulse_Rate  SYS  \
# 0     186.0  276914.0  92305.0  ...           1  28.9     0           0    0
# 1     186.0  230984.0  76995.0  ...           2  28.9     0           0    0
# 2     186.0  218470.0  72823.0  ...           3  28.9    89         104    0
# 3     186.0  203376.0  67792.0  ...           4  28.9    89         104    0
# 4     186.0  235723.0  78574.0  ...           5  28.9    89         101    0
#
#    DIA  Heart_rate  Resp_Rate   ST  Label
# 0    0           0          0  0.0      0
# ...

# %%
df1['Label'].value_counts()
# Out:
# Label
# 0    14272
# 1     2046
# Name: count, dtype: int64

# %%
df1.keys()
# Out:
# Index(['Dir', 'Flgs', 'SrcAddr', 'DstAddr', 'Sport', 'Dport', 'SrcBytes',
#        'DstBytes', 'SrcLoad', 'DstLoad', 'SrcGap', 'DstGap', 'SIntPkt',
#        'DIntPkt', 'SIntPktAct', 'DIntPktAct', 'SrcJitter', 'DstJitter',
#        'sMaxPktSz', 'dMaxPktSz', 'sMinPktSz', 'dMinPktSz', 'Dur', 'Trans',
#        'TotPkts', 'TotBytes', 'Load', 'Loss', 'pLoss', 'pSrcLoss', 'pDstLoss',
#        'Rate', 'SrcMac', 'DstMac', 'Packet_num', 'Temp', 'SpO2', 'Pulse_Rate',
#        'SYS', 'DIA', 'Heart_rate', 'Resp_Rate', 'ST', 'Label'],
#       dtype='object')

# %%
for cols in df1.keys():
    print(f'col: {cols} , values : {df1[cols].value_counts()}')
# Out:
# col: Dir , values : Dir
#    ->    16318
# Name: count, dtype: int64
# col: Flgs , values : Flgs
#  e            15237
#  M              924
#  eR             138
#  e s              8
#  M *              7
#  M d              3
#  MR               1
# Name: count, dtype: int64
# col: SrcAddr , values : SrcAddr
# 10.0.1.172    16318
# Name: count, dtype: int64
# col: DstAddr , values : DstAddr
# 10.0.1.150    16318
# Name: count, dtype: int64
# col: Sport , values : Sport
# 57458    2
# 51612    2
# 64273    2
# 50474    2
# 58059    1
#         ..
# 61224    1
# 61229    1
# 61232    1
# 61236    1
# 63969    1
# Name: count, Length: 16314, dtype: int64
# col: Dport , values : Dport
# 1111    16318
# Name: count, dtype: int64
# col: SrcBytes , values : SrcBytes
# 496.0     16228
# 436.0        35
# 556.0        21
# 806.0        11
# 562.0         4
# 310.0         4
# 430.0         3
# 502.0         3
# 1988.0        2
# 866.0         2
# 2298.0        1
# 1057.0        1
# ...

# %%
df2 = pd.read_csv('wustl_hdrl_2024.csv')
# Out:
# C:\Users\KARAN\AppData\Local\Temp\ipykernel_1924\3070449183.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('wustl_hdrl_2024.csv')

# %%
df2
# Out:
#           Dir        Flgs          SrcAddr      DstAddr  Sport  Dport  \
# 0          ->   e              192.168.3.2  192.168.2.2  36390   4022
# 1          ->   e              192.168.3.2  192.168.2.2  49608   4022
# 2          ->   e              192.168.3.2  192.168.2.2  34596   4022
# 3          ->   e d         78.151.208.250  192.168.2.2  18346   4022
# 4          ->   e d        143.109.155.233  192.168.2.2  18346   4022
# ...       ...         ...              ...          ...    ...    ...
# 145118     ->   e d         210.199.96.247  192.168.4.2   3617   4022
# 145119     ->   e d          52.213.241.61  192.168.4.2   3617   4022
# 145120     ->   e d          250.243.186.7  192.168.4.2   3617   4022
# 145121     ->   e           198.51.100.100  192.168.4.2  57484   4022
# 145122     ->   e           198.51.100.100  192.168.4.2  57486   4022
#
#         SrcBytes  DstBytes  SrcLoad   DstLoad  ...  sswap_sin  sswap_sout  \
# ...

# %%
df2.keys()
# Out:
# Index(['Dir', 'Flgs', 'SrcAddr', 'DstAddr', 'Sport', 'Dport', 'SrcBytes',
#        'DstBytes', 'SrcLoad', 'DstLoad', 'SrcGap', 'DstGap', 'SIntPkt',
#        'DIntPkt', 'SIntPktAct', 'DIntPktAct', 'SrcJitter', 'DstJitter',
#        'sMaxPktSz', 'dMaxPktSz', 'sMinPktSz', 'dMinPktSz', 'Dur', 'Trans',
#        'TotPkts', 'TotBytes', 'network_load', 'Loss', 'pLoss', 'pSrcLoss',
#        'pDstLoss', 'Rate', 'SrcMac', 'DstMac', 'IMEI', 'RTime', 'Packet_num',
#        'scputimes_user', 'scputimes_nice', 'scputimes_system',
#        'scputimes_idle', 'scputimes_iowait', 'scputimes_irq',
#        'scputimes_softirq', 'scputimes_steal', 'scputimes_guest',
#        'scputimes_guest_nice', 'scpustats_ctx_switches',
#        'scpustats_interrupts', 'scpustats_soft_interrupts',
#        'scpustats_syscalls', 'svmem_total', 'svmem_available', 'svmem_percent',
#        'svmem_used', 'svmem_free', 'svmem_active', 'svmem_inactive',
# ...

# %%
df2['Label'].value_counts()
# Out:
# Label
# 0    132884
# 1     12239
# Name: count, dtype: int64

# %%
df2.head()
# Out:
#      Dir        Flgs          SrcAddr      DstAddr  Sport  Dport  SrcBytes  \
# 0     ->   e              192.168.3.2  192.168.2.2  36390   4022    1651.0
# 1     ->   e              192.168.3.2  192.168.2.2  49608   4022    1673.0
# 2     ->   e              192.168.3.2  192.168.2.2  34596   4022    1650.0
# 3     ->   e d         78.151.208.250  192.168.2.2  18346   4022    1450.0
# 4     ->   e d        143.109.155.233  192.168.2.2  18346   4022    1452.0
#
#    DstBytes  SrcLoad   DstLoad  ...  sswap_sin  sswap_sout  sdiskusage_total  \
# 0     272.0  10440.0  1612.000  ...          0           0      502392610816
# 1     272.0  10576.0  1611.000  ...          0           0      502392610816
# 2     272.0  10364.0  1602.000  ...          0           0      502392610816
# 3     174.0      0.0   306.469  ...          0           0      502392610858
# 4     174.0      0.0   305.268  ...          0           0      502392610863
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145123 entries, 0 to 145122
# Data columns (total 77 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Dir                        145123 non-null  object
#  1   Flgs                       145123 non-null  object
#  2   SrcAddr                    145123 non-null  object
#  3   DstAddr                    145123 non-null  object
#  4   Sport                      145123 non-null  object
#  5   Dport                      145123 non-null  int64
#  6   SrcBytes                   145123 non-null  float64
#  7   DstBytes                   145123 non-null  float64
#  8   SrcLoad                    145123 non-null  float64
#  9   DstLoad                    145123 non-null  float64
#  10  SrcGap                     145123 non-null  float64
#  11  DstGap                     145123 non-null  float64
#  12  SIntPkt                    145123 non-null  float64
# ...

# %%
df2['Dir'].value_counts()
# Out:
# Dir
#    ->    145120
#   ->          1
# ->            1
#  ->           1
# Name: count, dtype: int64

# %%
df2 = df2.drop('Dir', axis = 1)

# %%
df2
# Out:
#               Flgs          SrcAddr      DstAddr  Sport  Dport  SrcBytes  \
# 0        e              192.168.3.2  192.168.2.2  36390   4022    1651.0
# 1        e              192.168.3.2  192.168.2.2  49608   4022    1673.0
# 2        e              192.168.3.2  192.168.2.2  34596   4022    1650.0
# 3        e d         78.151.208.250  192.168.2.2  18346   4022    1450.0
# 4        e d        143.109.155.233  192.168.2.2  18346   4022    1452.0
# ...            ...              ...          ...    ...    ...       ...
# 145118   e d         210.199.96.247  192.168.4.2   3617   4022    1453.0
# 145119   e d          52.213.241.61  192.168.4.2   3617   4022    1452.0
# 145120   e d          250.243.186.7  192.168.4.2   3617   4022    1450.0
# 145121   e           198.51.100.100  192.168.4.2  57484   4022    1648.0
# 145122   e           198.51.100.100  192.168.4.2  57486   4022    1649.0
#
#         DstBytes  SrcLoad   DstLoad  SrcGap  ...  sswap_sin  sswap_sout  \
# ...

# %%
df2['Flgs'].value_counts()
# Out:
# Flgs
#  e            135827
#  e d            9287
#  e s               5
#  e *               2
#  e g               1
#  eUd               1
# Name: count, dtype: int64
